# %% [markdown]
# ## Create batch pipeline

# %%
# Connect to your workspace
from azureml.core import Workspace
ws = Workspace.from_config()

# %% [markdown]
# ## Provision inference compute

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "mlopsbootcamp"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_DS2_v2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress.....
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Create a pipeline for batch inferencing

# %%
import os
# Create a folder for the experiment files
WORKDIR = os.path.dirname(os.getcwd())
experiment_folder = os.path.join(WORKDIR, 'batch_pipeline')
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch_pipeline

# %% [markdown]
# ## Get path to the model

# %%
from azureml.core import Model
model_list = Model.list(ws)
model_path = Model.get_model_path('fourier_regression', _workspace=ws)
print(model_list, model_path)
# Out:
# [Model(workspace=Workspace.create(name='mlworkspace', subscription_id='e7d71274-b7c4-47ed-9751-2505b563b918', resource_group='mlgroup'), name=fourier_regression, id=fourier_regression:1, version=1, tags={}, properties={})] azureml-models\fourier_regression\1\fourier.pkl

# %% [markdown]
# ## Load the model

# %%
import joblib
model = joblib.load(model_path)
model
# Out:
# LinearRegression()

# %% [markdown]
# ## Check the batch data

# %%
mini_batch = list()
for (dirpath, dirnames, filenames) in os.walk(os.path.join(WORKDIR, "batch-data")):
    mini_batch += [os.path.join(dirpath, file) for file in filenames]
for elem in mini_batch:
    print(elem)
# Out:
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-1.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-2.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-3.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-4.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-5.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-6.csv
# d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-data\batch-7.csv

# %% [markdown]
# ## Make prediction per batch

# %%
import numpy as np
def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',', skip_header=1)
        # Reshape into a 2-dimensional array for model input
        data = data[:, 1:]
        prediction = model.predict(data)
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), np.mean(prediction)))
    return resultList

result = run(mini_batch)
result
# Out:
# ['batch-1.csv: 99.93783767827078',
#  'batch-2.csv: 99.89835726364004',
#  'batch-3.csv: 89.52226883425273',
#  'batch-4.csv: 89.36492929530372',
#  'batch-5.csv: 100.80108846176175',
#  'batch-6.csv: 100.33507942766154',
#  'batch-7.csv: 100.09765850751842']

# %% [markdown]
# ## Summarize into python script

# %%
# %%writefile $experiment_folder\score.py

import os
import numpy as np
from azureml.core import Model
import joblib

def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('fourier_regression')
    model = joblib.load(model_path)

def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',', skip_header=1)
        # Reshape into a 2-dimensional array for model input
        data = data[:, 1:]
        prediction = model.predict(data)
        # log results (for application insights)
        log = 'Data:' + str(data) + ' - Prediction:' + str(prediction)
        print(log)
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), np.mean(prediction)))
    return resultList
# Out:
# Overwriting d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch_pipeline\score.py

# %% [markdown]
# ## Create conda environment for the pipeline

# %%
# %%writefile $experiment_folder\batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.8
# - numpy
# - pandas
# - scikit-learn
# - pip:
#     - azureml-core
#     - azureml-dataset-runtime[fuse]
#     - azureml-pipeline-core
#     - azureml-pipeline-steps
# Out:
# Overwriting d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch_pipeline\batch_environment.yml

# %% [markdown]
# ## Define run using environment

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# ## Configure batch pipeline steps

# %%
from datetime import datetime

from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig
from azureml.core.runconfig import DockerConfiguration

# Get the batch dataset for input
batch_data_set = ws.datasets['batch-data']

# Set the output location
default_ds = ws.get_default_datastore()
output_dir = OutputFileDatasetConfig(name='inferences')

# Define the parallel run step step configuration
parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="score.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallel_step_name = "batchscoring-" + datetime.now().strftime("%Y%m%d%H%M")

# Create the parallel run step
parallelrun_step = ParallelRunStep(
    name=parallel_step_name,
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('batch_data')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# ## Run the pipeline

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

# Create the pipeline
pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])

# Run the pipeline as an experiment
pipeline_run = Experiment(ws, 'pytown-energy-demand-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batchscoring-202108070039 [9a27a8f2][b7d9a36e-a870-49be-beda-dee6e9226323], (This step will run and generate new outputs)
# Submitted PipelineRun ce08e119-55df-42e0-b088-9521100eac90
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ce08e119-55df-42e0-b088-9521100eac90?wsid=/subscriptions/e7d71274-b7c4-47ed-9751-2505b563b918/resourcegroups/mlgroup/workspaces/mlworkspace&tid=a0f1cacd-618c-4403-b945-76fb3d6874e5
# PipelineRunId: ce08e119-55df-42e0-b088-9521100eac90
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ce08e119-55df-42e0-b088-9521100eac90?wsid=/subscriptions/e7d71274-b7c4-47ed-9751-2505b563b918/resourcegroups/mlgroup/workspaces/mlworkspace&tid=a0f1cacd-618c-4403-b945-76fb3d6874e5
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 2c56b7fc-1633-4648-9806-a5562cadaa04
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2c56b7fc-1633-4648-9806-a5562cadaa04?wsid=/subscriptions/e7d71274-b7c4-47ed-9751-2505b563b918/resourcegroups/mlgroup/workspaces/mlworkspace&tid=a0f1cacd-618c-4403-b945-76fb3d6874e5
# StepRun( batchscoring-202108070039 ) Status: NotStarted
# StepRun( batchscoring-202108070039 ) Status: Queued
# StepRun( batchscoring-202108070039 ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/08/06 22:40:46 Downloading source code...
# 2021/08/06 22:40:47 Finished downloading source code
# 2021/08/06 22:40:48 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/08/06 22:40:48 Successfully set up Docker network: acb_default_network
# 2021/08/06 22:40:48 Setting up Docker configuration...
# 2021/08/06 22:40:49 Successfully set up Docker configuration
# 2021/08/06 22:40:49 Logging in to registry: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io
# 2021/08/06 22:40:50 Successfully logged into ca3398504bbe4b78b7aac0adb9726e74.azurecr.io
# 2021/08/06 22:40:50 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/08/06 22:40:50 Scanning for dependencies...
# 2021/08/06 22:40:51 Successfully scanned dependencies
# 2021/08/06 22:40:51 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 4bbfd2c87b75: Pulling fs layer
# d2e110be24e1: Pulling fs layer
# 889a7173dcfe: Pulling fs layer
# 7a7a145ebf57: Pulling fs layer
# 1ae81884420d: Pulling fs layer
# fcdf07e25452: Pulling fs layer
# 95262654cd7f: Pulling fs layer
# 520cb0fab4f5: Pulling fs layer
# 00c1c086d027: Pulling fs layer
# 282c4a3b6fb6: Pulling fs layer
# f4201c7ca826: Pulling fs layer
# 1ae81884420d: Waiting
# fcdf07e25452: Waiting
# 95262654cd7f: Waiting
# 520cb0fab4f5: Waiting
# 00c1c086d027: Waiting
# 282c4a3b6fb6: Waiting
# f4201c7ca826: Waiting
# 7a7a145ebf57: Waiting
# 889a7173dcfe: Verifying Checksum
# 889a7173dcfe: Download complete
# d2e110be24e1: Verifying Checksum
# d2e110be24e1: Download complete
# 7a7a145ebf57: Verifying Checksum
# 7a7a145ebf57: Download complete
# fcdf07e25452: Download complete
# 4bbfd2c87b75: Verifying Checksum
# 4bbfd2c87b75: Download complete
# 520cb0fab4f5: Verifying Checksum
# 520cb0fab4f5: Download complete
# 1ae81884420d: Verifying Checksum
# 1ae81884420d: Download complete
# 282c4a3b6fb6: Verifying Checksum
# 282c4a3b6fb6: Download complete
# 95262654cd7f: Verifying Checksum
# 95262654cd7f: Download complete
# f4201c7ca826: Verifying Checksum
# f4201c7ca826: Download complete
# 4bbfd2c87b75: Pull complete
# 00c1c086d027: Verifying Checksum
# 00c1c086d027: Download complete
# d2e110be24e1: Pull complete
# 889a7173dcfe: Pull complete
#
# 7a7a145ebf57: Pull complete
# 1ae81884420d: Pull complete
# fcdf07e25452: Pull complete
# 95262654cd7f: Pull complete
# 520cb0fab4f5: Pull complete
# 00c1c086d027: Pull complete
# 282c4a3b6fb6: Pull complete
# f4201c7ca826: Pull complete
# Digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#  ---> 6ba46986c29e
# Step 2/18 : USER root
#  ---> Running in c906b48ff317
# Removing intermediate container c906b48ff317
#  ---> 677bc3425cc6
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 66ae8a6264aa
# Removing intermediate container 66ae8a6264aa
#  ---> d16cbc812344
# Step 4/18 : WORKDIR /
#  ---> Running in 3d9f3b802106
# Removing intermediate container 3d9f3b802106
#  ---> 286e0f53ae12
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 66879b7b8e98
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 71a61baef23e
# Removing intermediate container 71a61baef23e
#  ---> f9329391aefa
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 402234b1e566
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 55d0846c5bb7
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# mkl-2021.3.0         | 141.2 MB  |            |   0%
# mkl-2021.3.0         | 141.2 MB  | 2          |   2%
# mkl-2021.3.0         | 141.2 MB  | 8          |   9%
# mkl-2021.3.0         | 141.2 MB  | #4         |  15%
# mkl-2021.3.0         | 141.2 MB  | ##         |  20%
# mkl-2021.3.0         | 141.2 MB  | ##6        |  26%
# mkl-2021.3.0         | 141.2 MB  | ###2       |  33%
# mkl-2021.3.0         | 141.2 MB  | ###9       |  39%
# mkl-2021.3.0         | 141.2 MB  | ####5      |  46%
# mkl-2021.3.0         | 141.2 MB  | #####2     |  52%
# mkl-2021.3.0         | 141.2 MB  | #####8     |  58%
# mkl-2021.3.0         | 141.2 MB  | ######4    |  65%
# mkl-2021.3.0         | 141.2 MB  | #######1   |  71%
# mkl-2021.3.0         | 141.2 MB  | #######7   |  78%
# mkl-2021.3.0         | 141.2 MB  | ########4  |  84%
# mkl-2021.3.0         | 141.2 MB  | #########  |  91%
# mkl-2021.3.0         | 141.2 MB  | #########7 |  97%
# mkl-2021.3.0         | 141.2 MB  | ########## | 100%
#
# setuptools-52.0.0    | 714 KB    |            |   0%
# setuptools-52.0.0    | 714 KB    | ########## | 100%
#
# libffi-3.3           | 50 KB     |            |   0%
# libffi-3.3           | 50 KB     | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# bottleneck-1.3.2     | 125 KB    |            |   0%
# bottleneck-1.3.2     | 125 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# scipy-1.6.2          | 15.6 MB   |            |   0%
# scipy-1.6.2          | 15.6 MB   | ####8      |  48%
# scipy-1.6.2          | 15.6 MB   | ########## | 100%
# scipy-1.6.2          | 15.6 MB   | ########## | 100%
#
# pytz-2021.1          | 181 KB    |            |   0%
# pytz-2021.1          | 181 KB    | ########## | 100%
# pytz-2021.1          | 181 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.4 MB    |            |   0%
# scikit-learn-0.24.2  | 5.4 MB    | #####1     |  52%
# scikit-learn-0.24.2  | 5.4 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.4 MB    | ########## | 100%
#
# ld_impl_linux-64-2.3 | 586 KB    |            |   0%
# ld_impl_linux-64-2.3 | 586 KB    | ########## | 100%
#
# numpy-1.20.3         | 23 KB     |            |   0%
# numpy-1.20.3         | 23 KB     | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# numexpr-2.7.3        | 188 KB    |            |   0%
# numexpr-2.7.3        | 188 KB    | ########## | 100%
#
# ncurses-6.2          | 817 KB    |            |   0%
# ncurses-6.2          | 817 KB    | ########## | 100%
# ncurses-6.2          | 817 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# readline-8.1         | 362 KB    |            |   0%
# readline-8.1         | 362 KB    | ########## | 100%
#
# openssl-1.1.1k       | 2.5 MB    |            |   0%
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
#
# mkl_random-1.2.2     | 308 KB    |            |   0%
# mkl_random-1.2.2     | 308 KB    | ########## | 100%
#
# numpy-base-1.20.3    | 4.5 MB    |            |   0%
# numpy-base-1.20.3    | 4.5 MB    | ########## | 100%
# numpy-base-1.20.3    | 4.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# pandas-1.3.1         | 9.6 MB    |            |   0%
# pandas-1.3.1         | 9.6 MB    | #####4     |  54%
# pandas-1.3.1         | 9.6 MB    | ########## | 100%
# pandas-1.3.1         | 9.6 MB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# python-3.8.11        | 18.2 MB   |            |   0%
# python-3.8.11        | 18.2 MB   | ###2       |  32%
# python-3.8.11        | 18.2 MB   | ########2  |  82%
# python-3.8.11        | 18.2 MB   | ########## | 100%
#
# certifi-2021.5.30    | 138 KB    |            |   0%
# certifi-2021.5.30    | 138 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 180 KB    |            |   0%
# mkl_fft-1.3.0        | 180 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# sqlite-3.36.0        | 990 KB    |            |   0%
# sqlite-3.36.0        | 990 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# mkl-service-2.4.0    | 59 KB     |            |   0%
# mkl-service-2.4.0    | 59 KB     | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.akut8hy4.requirements.txt']
# Pip subprocess output:
# Collecting azureml-core
#   Downloading azureml_core-1.33.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataset-runtime[fuse]
#   Downloading azureml_dataset_runtime-1.33.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-pipeline-core
#   Downloading azureml_pipeline_core-1.33.0-py3-none-any.whl (312 kB)
# Collecting azureml-pipeline-steps
#   Downloading azureml_pipeline_steps-1.33.0-py3-none-any.whl (70 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting urllib3<=1.26.5,>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.0.0-py2.py3-none-any.whl (312 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib/python3.8/site-packages (from azureml-core->-r /azureml-environment-setup/condaenv.akut8hy4.requirements.txt (line 1)) (2.8.2)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib/python3.8/site-packages (from azureml-core->-r /azureml-environment-setup/condaenv.akut8hy4.requirements.txt (line 1)) (2021.1)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting azureml-dataprep<2.21.0a,>=2.20.0a
#   Downloading azureml_dataprep-2.20.1-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]->-r /azureml-environment-setup/condaenv.akut8hy4.requirements.txt (line 2)) (1.20.3)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp38-cp38-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-train-core~=1.33.0
#   Downloading azureml_train_core-1.33.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-train-automl-client~=1.33.0
#   Downloading azureml_train_automl_client-1.33.0-py3-none-any.whl (128 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.17.0-py2.py3-none-any.whl (165 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib/python3.8/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core->-r /azureml-environment-setup/condaenv.akut8hy4.requirements.txt (line 1)) (1.16.0)
# Collecting azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0
#   Downloading azureml_dataprep_rslex-1.18.1-cp38-cp38-manylinux1_x86_64.whl (10.4 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.13.0-py2.py3-none-any.whl (67 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azureml-telemetry~=1.33.0
#   Downloading azureml_telemetry-1.33.0-py3-none-any.whl (30 kB)
# Collecting azureml-automl-core~=1.33.0
#   Downloading azureml_automl_core-1.33.0-py3-none-any.whl (213 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.33.0
#   Downloading azureml_train_restclients_hyperdrive-1.33.0-py3-none-any.whl (19 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp38-cp38-manylinux1_x86_64.whl (411 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.1.1-py2.py3-none-any.whl (68 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib/python3.8/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core->-r /azureml-environment-setup/condaenv.akut8hy4.requirements.txt (line 1)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp38-cp38-manylinux1_x86_64.whl (570 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=d3d0f65559d459736c21c1ab712844fc26225fd211e2a70ed5738293c547710c
#   Stored in directory: /root/.cache/pip/wheels/7f/41/10/f70b83a1164fdb95e7bc37bace13114a024227e56c2fee02bb
# Successfully built fusepy
# Installing collected packages: pycparser, urllib3, idna, charset-normalizer, cffi, requests, PyJWT, oauthlib, cryptography, requests-oauthlib, isodate, portalocker, msrest, msal, azure-core, adal, websocket-client, ruamel.yaml.clib, pyopenssl, pyasn1, msrestazure, msal-extensions, jeepney, distro, backports.weakref, azure-mgmt-core, azure-common, SecretStorage, ruamel.yaml, pathspec, ndg-httpsclient, jsonpickle, jmespath, dotnetcore2, docker, contextlib2, cloudpickle, backports.tempfile, azureml-dataprep-rslex, azureml-dataprep-native, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-identity, azure-graphrbac, pyarrow, azureml-dataprep, azureml-core, applicationinsights, azureml-telemetry, azureml-dataset-runtime, azureml-train-restclients-hyperdrive, azureml-automl-core, fusepy, azureml-train-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps
# Successfully installed PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.17.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.0.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.33.0 azureml-core-1.33.0 azureml-dataprep-2.20.1 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.18.1 azureml-dataset-runtime-1.33.0 azureml-pipeline-core-1.33.0 azureml-pipeline-steps-1.33.0 azureml-telemetry-1.33.0 azureml-train-automl-client-1.33.0 azureml-train-core-1.33.0 azureml-train-restclients-hyperdrive-1.33.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.6 charset-normalizer-2.0.4 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.7 distro-1.6.0 docker-4.4.4 dotnetcore2-2.1.21 fusepy-3.0.1 idna-3.2 isodate-0.6.0 jeepney-0.7.1 jmespath-0.10.0 jsonpickle-2.0.0 msal-1.13.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pathspec-0.9.0 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 urllib3-1.26.5 websocket-client-1.1.1
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 55d0846c5bb7
#  ---> 1bcad80337cf
# Step 9/18 : ENV PATH /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/bin:$PATH
#  ---> Running in 3c7614d6a65b
# Removing intermediate container 3c7614d6a65b
#  ---> dd85c6adf12a
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 3f7f4000fe10
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 2446402fd852
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a
#  ---> Running in 5536be6b5c5e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 5536be6b5c5e
#  ---> d84f99ca0b82
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a
#  ---> Running in d8c7350b6a66
# Removing intermediate container d8c7350b6a66
#  ---> 978211564125
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_db7ebbb9571a6977a2f98ab3eaae138a/lib:$LD_LIBRARY_PATH
#  ---> Running in cefee5116c57
# Removing intermediate container cefee5116c57
#  ---> 0ddbb7414467
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 39967f193523
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 8a05ce83a55f
# Removing intermediate container 8a05ce83a55f
#  ---> 9157a0047beb
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 4389da850ccd
# Removing intermediate container 4389da850ccd
#  ---> 6162d7190a82
# Step 18/18 : CMD ["bash"]
#  ---> Running in 28885ad36e71
# Removing intermediate container 28885ad36e71
#  ---> 1fb9804138be
# Successfully built 1fb9804138be
# Successfully tagged ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:latest
# Successfully tagged ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:1
# 2021/08/06 22:43:40 Successfully executed container: acb_step_0
# 2021/08/06 22:43:40 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/08/06 22:43:40 Pushing image: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:1, attempt 1
# The push refers to repository [ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722]
# d581eed422a2: Preparing
# 98cbe9290bfb: Preparing
# a50ab6efd69e: Preparing
# 6da7d0f05c38: Preparing
# b9e34c4c91a4: Preparing
# 07d4045b9f3e: Preparing
# 8967b60c98ea: Preparing
# 12b65af4eb61: Preparing
# 2e0ddb95a1ab: Preparing
# fe09032048fd: Preparing
# cbe733e9771d: Preparing
# 74218ef6464a: Preparing
# 5ba1f0778181: Preparing
# 658e73e9fcdf: Preparing
# b48835f37b9c: Preparing
# a7c59d42f9e5: Preparing
# bb7a0d4412a3: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# 07d4045b9f3e: Waiting
# 8967b60c98ea: Waiting
# 12b65af4eb61: Waiting
# 2e0ddb95a1ab: Waiting
# fe09032048fd: Waiting
# cbe733e9771d: Waiting
# 74218ef6464a: Waiting
# 5ba1f0778181: Waiting
# 658e73e9fcdf: Waiting
# b48835f37b9c: Waiting
# a7c59d42f9e5: Waiting
# bb7a0d4412a3: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# a50ab6efd69e: Pushed
# 6da7d0f05c38: Pushed
# 98cbe9290bfb: Pushed
# d581eed422a2: Pushed
# 07d4045b9f3e: Pushed
# 8967b60c98ea: Pushed
# 12b65af4eb61: Pushed
# 2e0ddb95a1ab: Pushed
# fe09032048fd: Pushed
# cbe733e9771d: Pushed
# 5ba1f0778181: Pushed
# 74218ef6464a: Pushed
# a7c59d42f9e5: Pushed
# 5f08512fd434: Pushed
# c7bb31fc0e08: Pushed
# b48835f37b9c: Pushed
#
# 658e73e9fcdf: Pushed
# 50858308da3d: Pushed
# bb7a0d4412a3: Pushed
#
# b9e34c4c91a4: Pushed
# 1: digest: sha256:e05ce897c26682424de7759bce556a1c0fd1ae95a99162336d50e91072626595 size: 4514
# 2021/08/06 22:45:50 Successfully pushed image: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:1
# 2021/08/06 22:45:50 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/08/06 22:45:50 Pushing image: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:latest, attempt 1
# The push refers to repository [ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722]
# d581eed422a2: Preparing
# 98cbe9290bfb: Preparing
# a50ab6efd69e: Preparing
# 6da7d0f05c38: Preparing
# b9e34c4c91a4: Preparing
# 07d4045b9f3e: Preparing
# 8967b60c98ea: Preparing
# 12b65af4eb61: Preparing
# 2e0ddb95a1ab: Preparing
# fe09032048fd: Preparing
# cbe733e9771d: Preparing
# 74218ef6464a: Preparing
# 5ba1f0778181: Preparing
# 658e73e9fcdf: Preparing
# b48835f37b9c: Preparing
# a7c59d42f9e5: Preparing
# bb7a0d4412a3: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# 07d4045b9f3e: Waiting
# 8967b60c98ea: Waiting
# 12b65af4eb61: Waiting
# 2e0ddb95a1ab: Waiting
# fe09032048fd: Waiting
# cbe733e9771d: Waiting
# 74218ef6464a: Waiting
# 5ba1f0778181: Waiting
# 658e73e9fcdf: Waiting
# b48835f37b9c: Waiting
# a7c59d42f9e5: Waiting
# bb7a0d4412a3: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# 6da7d0f05c38: Layer already exists
# d581eed422a2: Layer already exists
# b9e34c4c91a4: Layer already exists
# 98cbe9290bfb: Layer already exists
# a50ab6efd69e: Layer already exists
# 07d4045b9f3e: Layer already exists
# 8967b60c98ea: Layer already exists
# 12b65af4eb61: Layer already exists
# 2e0ddb95a1ab: Layer already exists
# fe09032048fd: Layer already exists
# cbe733e9771d: Layer already exists
# 74218ef6464a: Layer already exists
# b48835f37b9c: Layer already exists
# 5ba1f0778181: Layer already exists
# 658e73e9fcdf: Layer already exists
# a7c59d42f9e5: Layer already exists
# bb7a0d4412a3: Layer already exists
# 5f08512fd434: Layer already exists
# c7bb31fc0e08: Layer already exists
# 50858308da3d: Layer already exists
# latest: digest: sha256:e05ce897c26682424de7759bce556a1c0fd1ae95a99162336d50e91072626595 size: 4514
# 2021/08/06 22:45:52 Successfully pushed image: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io/azureml/azureml_9d4bd7aa24a84c841175459532efd722:latest
# 2021/08/06 22:45:52 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 169.967636)
# 2021/08/06 22:45:52 Populating digests for step ID: acb_step_0...
# 2021/08/06 22:45:53 Successfully populated digests for step ID: acb_step_0
# 2021/08/06 22:45:53 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 129.920639)
# 2021/08/06 22:45:53 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.718569)
# 2021/08/06 22:45:53 The following dependencies were found:
# 2021/08/06 22:45:53
# - image:
#     registry: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io
#     repository: azureml/azureml_9d4bd7aa24a84c841175459532efd722
#     tag: latest
#     digest: sha256:e05ce897c26682424de7759bce556a1c0fd1ae95a99162336d50e91072626595
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
# - image:
#     registry: ca3398504bbe4b78b7aac0adb9726e74.azurecr.io
#     repository: azureml/azureml_9d4bd7aa24a84c841175459532efd722
#     tag: "1"
#     digest: sha256:e05ce897c26682424de7759bce556a1c0fd1ae95a99162336d50e91072626595
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
#
# Run ID: cb1 was successful after 5m9s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_293a0872081edbffeadc4f477d74765f64272ba8de80890003c90aae09da20ac_d.txt
# ========================================================================================================================
# 2021-08-06T22:54:02Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=11461 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-08-06T22:54:02Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/mounts/workspaceblobstore
# 2021-08-06T22:54:03Z The vmsize standard_ds2_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-08-06T22:54:03Z Starting output-watcher...
# 2021-08-06T22:54:03Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_37b71d944131a5da3ec055f8261503ea
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 08594b643883: Pulling fs layer
# 5d0f4c10c7b3: Pulling fs layer
# 9087fc082d04: Pulling fs layer
# c4eced8bb9ef: Pulling fs layer
# e31a66accdee: Pulling fs layer
# 0eecd57731f6: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 08594b643883: Waiting
# 5d0f4c10c7b3: Waiting
# 9087fc082d04: Waiting
# c4eced8bb9ef: Waiting
# e31a66accdee: Waiting
# 0eecd57731f6: Waiting
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 08594b643883: Verifying Checksum
# 08594b643883: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 9087fc082d04: Verifying Checksum
# 9087fc082d04: Download complete
# c4eced8bb9ef: Verifying Checksum
# c4eced8bb9ef: Download complete
# e31a66accdee: Verifying Checksum
# e31a66accdee: Download complete
# 0eecd57731f6: Verifying Checksum
# 0eecd57731f6: Download complete
# 5d0f4c10c7b3: Verifying Checksum
# 5d0f4c10c7b3: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_acf403f835b27efc5466d6e75a86809a5f9527a29a61b8043fd3157924c39fbc_d.txt
# ===============================================================================================================
# [2021-08-06T22:54:31.682284] Entering job preparation.
# [2021-08-06T22:54:32.239133] Starting job preparation.
# [2021-08-06T22:54:32.239161] Extracting the control code.
# [2021-08-06T22:54:32.239741] Starting extract_project.
# [2021-08-06T22:54:32.239804] Starting to extract zip file.
# [2021-08-06T22:54:32.263559] Finished extracting zip file.
# [2021-08-06T22:54:32.267129] Using urllib.request Python 3.0 or later
# [2021-08-06T22:54:32.267170] Start fetching snapshots.
# [2021-08-06T22:54:32.267314] Start fetching snapshot.
# [2021-08-06T22:54:32.267334] Retrieving project from snapshot: 1c123578-1bc3-4e1f-b52d-119a7907dc31
# Starting the daemon thread to refresh tokens in background for process with pid = 52
# [2021-08-06T22:54:32.680820] Finished fetching snapshot.
# [2021-08-06T22:54:32.680872] Start fetching snapshot.
# [2021-08-06T22:54:32.680887] Retrieving project from snapshot: 30b2a30d-4ed8-463f-8705-8c92c304adce
# [2021-08-06T22:54:39.275025] Finished fetching snapshot.
# [2021-08-06T22:54:39.275062] Finished fetching snapshots.
# [2021-08-06T22:54:39.275073] Finished extract_project.
# [2021-08-06T22:54:39.275416] Finished fetching and extracting the control code.
# [2021-08-06T22:54:39.283877] Start run_history_prep.
# [2021-08-06T22:54:39.290909] Job preparation is complete.
# [2021-08-06T22:54:39.291201] Entering Data Context Managers in Sidecar
# [2021-08-06T22:54:39.292077] Running Sidecar prep cmd...
# [2021-08-06T22:54:39.676542] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04
# [2021-08-06T22:54:39.677320] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.32.0 azureml-dataprep==2.20.1. Session id: 3c92ecb4-6a11-4efd-920a-8ae638963faa. Run id: 2c56b7fc-1633-4648-9806-a5562cadaa04.
# Processing 'batch_data'.
# Mode: 'mount'.
# Path on compute is specified: 'False'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "25075a8a-3137-4feb-8f63-9c94fb434092",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data for pytown demand energy forecast",
#     "workspace": "Workspace.create(name='mlworkspace', subscription_id='e7d71274-b7c4-47ed-9751-2505b563b918', resource_group='mlgroup')"
#   }
# }
# Mounting batch_data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092.
# Mounted batch_data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092 as folder.
# Processing 'inferences'.
# Mode: 'mount'.
# Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore'.
# Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore.
# Exit __enter__ of DatasetContextManager
# Set Dataset batch_data's target path to /mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092
# Set OutputDataset inferences's target path to /tmp/3d8f97bc-2fb8-40f6-86fc-123ae32136eb
# [2021-08-06T22:54:52.715228] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-08-06T22:54:53.394301] Ran Sidecar prep cmd.
# [2021-08-06T22:54:53.394418] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/65_job_prep-tvmps_293a0872081edbffeadc4f477d74765f64272ba8de80890003c90aae09da20ac_d.txt
# ===============================================================================================================
# [2021-08-06T22:54:36.122984] Entering job preparation.
# [2021-08-06T22:54:36.686238] Starting job preparation.
# [2021-08-06T22:54:36.686273] Extracting the control code.
# [2021-08-06T22:54:36.686648] Starting extract_project.
# [2021-08-06T22:54:36.686689] Starting to extract zip file.
# [2021-08-06T22:54:36.708989] Finished extracting zip file.
# [2021-08-06T22:54:36.712633] Using urllib.request Python 3.0 or later
# [2021-08-06T22:54:36.712672] Start fetching snapshots.
# [2021-08-06T22:54:36.712705] Start fetching snapshot.
# [2021-08-06T22:54:36.712789] Retrieving project from snapshot: 1c123578-1bc3-4e1f-b52d-119a7907dc31
# Starting the daemon thread to refresh tokens in background for process with pid = 51
# [2021-08-06T22:54:36.921172] Finished fetching snapshot.
# [2021-08-06T22:54:36.921215] Start fetching snapshot.
# [2021-08-06T22:54:36.921230] Retrieving project from snapshot: 30b2a30d-4ed8-463f-8705-8c92c304adce
# [2021-08-06T22:54:43.016707] Finished fetching snapshot.
# [2021-08-06T22:54:43.016741] Finished fetching snapshots.
# [2021-08-06T22:54:43.016751] Finished extract_project.
# [2021-08-06T22:54:43.016817] Finished fetching and extracting the control code.
# [2021-08-06T22:54:43.025238] Start run_history_prep.
# [2021-08-06T22:54:43.031797] Job preparation is complete.
# [2021-08-06T22:54:43.032083] Entering Data Context Managers in Sidecar
# [2021-08-06T22:54:43.032938] Running Sidecar prep cmd...
# [2021-08-06T22:54:43.429006] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04
# [2021-08-06T22:54:43.430408] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.32.0 azureml-dataprep==2.20.1. Session id: 1fe6a7cf-c43f-4492-a0ac-cec699993ae9. Run id: 2c56b7fc-1633-4648-9806-a5562cadaa04.
# Processing 'batch_data'.
# Mode: 'mount'.
# Path on compute is specified: 'False'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "25075a8a-3137-4feb-8f63-9c94fb434092",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data for pytown demand energy forecast",
#     "workspace": "Workspace.create(name='mlworkspace', subscription_id='e7d71274-b7c4-47ed-9751-2505b563b918', resource_group='mlgroup')"
#   }
# }
# Mounting batch_data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092.
# Mounted batch_data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092 as folder.
# Processing 'inferences'.
# Mode: 'mount'.
# Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore'.
# Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore.
# Exit __enter__ of DatasetContextManager
# Set Dataset batch_data's target path to /mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092
# Set OutputDataset inferences's target path to /tmp/3d8f97bc-2fb8-40f6-86fc-123ae32136eb
# [2021-08-06T22:54:55.521837] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-08-06T22:54:56.286957] Ran Sidecar prep cmd.
# [2021-08-06T22:54:56.287180] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/08/06 22:55:31 Starting App Insight Logger for task:  runTaskLet
# 2021/08/06 22:55:31 Version: 3.0.01676.0004 Branch: 2021-07-23 Commit: 2766ca7
# 2021/08/06 22:55:31 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/08/06 22:55:31 Send process info logs to master server succeeded
# 2021/08/06 22:55:31 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/08/06 22:55:31 Send process info logs to master server succeeded
# [2021-08-06T22:55:31.910555] Entering context manager injector.
# [2021-08-06T22:55:32.324396] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.32.0', '--scoring_module_name', 'score.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'batch_data'])
# Script type = None
# [2021-08-06T22:55:32.328352] Entering Run History Context Manager.
# [2021-08-06T22:55:33.406139] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04
# [2021-08-06T22:55:33.406425] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.32.0', '--scoring_module_name', 'score.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'batch_data']
# [2021-08-06T22:55:33.406454] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.32.0', '--scoring_module_name', 'score.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/tmp/3d8f97bc-2fb8-40f6-86fc-123ae32136eb', '--input_fds_0', 'batch_data']
#
# 2021/08/06 22:55:36 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_293a0872081edbffeadc4f477d74765f64272ba8de80890003c90aae09da20ac_d.txt
# ===============================================================================================================
# [2021-08-06T22:56:40.441951] Entering job release
# [2021-08-06T22:56:41.224729] job release stage : copy_batchai_cached_logs starting...
# [2021-08-06T22:56:41.224769] job release stage : copy_batchai_cached_logs completed...
# [2021-08-06T22:56:41.224931] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-08-06T22:56:41.225998] Running Sidecar release cmd...
# [2021-08-06T22:56:41.235425] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/batch_data_25075a8a-3137-4feb-8f63-9c94fb434092.
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlworkspace/azureml/2c56b7fc-1633-4648-9806-a5562cadaa04/wd/inferences_workspaceblobstore.
# Exit __exit__ of DatasetContextManager
# [2021-08-06T22:56:41.280535] Removing absolute paths from host...
# [2021-08-06T22:56:41.281320] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-08-06T22:56:41.878904] Ran Sidecar release cmd.
#
# StepRun(batchscoring-202108070039) Execution Summary
# =====================================================
# StepRun( batchscoring-202108070039 ) Status: Finished
# {'runId': '2c56b7fc-1633-4648-9806-a5562cadaa04', 'target': 'mlopsbootcamp', 'status': 'Completed', 'startTimeUtc': '2021-08-06T22:54:00.380594Z', 'endTimeUtc': '2021-08-06T22:57:00.226439Z', 'properties': {'ContentSnapshotId': '1c123578-1bc3-4e1f-b52d-119a7907dc31', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'b7d9a36e-a870-49be-beda-dee6e9226323', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9a27a8f2', 'azureml.pipelinerunid': 'ce08e119-55df-42e0-b088-9521100eac90', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.RuntimeType': 'Hosttools', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '25075a8a-3137-4feb-8f63-9c94fb434092'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'batch_data', 'mechanism': 'Mount'}}, {'dataset': {'id': 'a14a856e-758e-4a29-89de-86067151d162'}, 'consumptionDetails': {'type': 'Reference'}}], 'outputDatasets': [{'identifier': {'savedId': 'a14a856e-758e-4a29-89de-86067151d162'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/2c56b7fc-1633-4648-9806-a5562cadaa04/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "a14a856e-758e-4a29-89de-86067151d162",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='mlworkspace', subscription_id='e7d71274-b7c4-47ed-9751-2505b563b918', resource_group='mlgroup')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.32.0', '--scoring_module_name', 'score.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'batch_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mlopsbootcamp', 'dataReferences': {}, 'data': {'batch_data': {'dataLocation': {'dataset': {'id': '25075a8a-3137-4feb-8f63-9c94fb434092', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'batch_data', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': '/tmp/3d8f97bc-2fb8-40f6-86fc-123ae32136eb/', 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2021-08-06T22:40:35Z_00cd096b', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.8', 'numpy', 'pandas', 'scikit-learn', {'pip': ['azureml-core', 'azureml-dataset-runtime[fuse]', 'azureml-pipeline-core', 'azureml-pipeline-steps']}], 'name': 'azureml_db7ebbb9571a6977a2f98ab3eaae138a'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': 'westus2', 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard'}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlworkspace2463885495.blob.core.windows.net/azureml/ExperimentRun/dcid.2c56b7fc-1633-4648-9806-a556 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ce08e119-55df-42e0-b088-9521100eac90', 'status': 'Completed', 'startTimeUtc': '2021-08-06T22:39:32.256482Z', 'endTimeUtc': '2021-08-06T22:57:03.476236Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlworkspace2463885495.blob.core.windows.net/azureml/ExperimentRun/dcid.ce08e119-55df-42e0-b088-9521100eac90/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=nZ8RXahJTAQWidTBommGqpK9zwUdjX0YNX7syVgUbwQ%3D&st=2021-08-06T22%3A30%3A38Z&se=2021-08-07T06%3A40%3A38Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlworkspace2463885495.blob.core.windows.net/azureml/ExperimentRun/dcid.ce08e119-55df-42e0-b088-9521100eac90/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=mqAKlShSv6wmgjcY2hpJRDnH5VYj8BhugXq%2FL%2F%2Ffp14%3D&st=2021-08-06T22%3A30%3A38Z&se=2021-08-07T06%3A40%3A38Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlworkspace2463885495.blob.core.windows.net/azureml/ExperimentRun/dcid.ce08e119-55df-42e0-b088-9521100eac90/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=8CbvPX8ZeAJXSjG0brnsWrHoVDQchUrH1xKxGxCKJCs%3D&st=2021-08-06T22%3A30%3A38Z&se=2021-08-07T06%3A40%3A38Z&sp=r'}, 'submittedBy': 'Iemke Steunebrink'}
# 'Finished'

# %% [markdown]
# ## Retrieve predictions

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
BATCH_RESULTS = os.path.join(WORKDIR, 'batch-results')
shutil.rmtree(BATCH_RESULTS, ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path=BATCH_RESULTS)

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk(BATCH_RESULTS):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#           File  Prediction
# 0  batch-1.csv   99.937838
# 1  batch-2.csv   99.898357
# 2  batch-3.csv   89.522269
# 3  batch-4.csv   89.364929
# 4  batch-5.csv  100.801088
# 5  batch-6.csv  100.335079
# 6  batch-7.csv  100.097659

# %% [markdown]
# ## Load predictions into data storage

# %%
datastore = ws.get_default_datastore()
datastore.upload(src_dir=BATCH_RESULTS, target_path="batch-results", overwrite=True, show_progress=True)
# Out:
# Uploading an estimated of 1 files
# Uploading d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-results\dataset\2c56b7fc-1633-4648-9806-a5562cadaa04\inferences\parallel_run_step.txt
# Uploaded d:\DS\MLOps-Bootcamp-2021\MLOps-Bootcamp-2021\batch-results\dataset\2c56b7fc-1633-4648-9806-a5562cadaa04\inferences\parallel_run_step.txt, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_7a28a2977434476f9c136e1907ec1359

# %% [markdown]
# ## Publish the pipeline

# %%
published_pipeline = pipeline_run.publish_pipeline(name='Fourier_regression_batch_prediction_pipeline',
                                                   description='Batch scoring using linear regression model with Fourier ML features',
                                                   version='1.0')

published_pipeline
# Out:
# Pipeline(Name: Fourier_regression_batch_prediction_pipeline,
# Id: bb3d5fd1-92f0-4141-a6c7-e64ad9cb4547,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/e7d71274-b7c4-47ed-9751-2505b563b918/resourceGroups/mlgroup/providers/Microsoft.MachineLearningServices/workspaces/mlworkspace/PipelineRuns/PipelineSubmit/bb3d5fd1-92f0-4141-a6c7-e64ad9cb4547)

# %% [markdown]
# ## Get REST endpoint

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/e7d71274-b7c4-47ed-9751-2505b563b918/resourceGroups/mlgroup/providers/Microsoft.MachineLearningServices/workspaces/mlworkspace/PipelineRuns/PipelineSubmit/bb3d5fd1-92f0-4141-a6c7-e64ad9cb4547

# %% [markdown]
# ## Schedule the pipeline to run every Monday at 04:00 in the morning (02:00 UTC)

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

weekly = ScheduleRecurrence(frequency='Week', interval=1, week_days=["Monday"], time_of_day="02:00")
pipeline_schedule = Schedule.create(ws, name='Weekly Predictions',
                                        description='batch inferencing',
                                        pipeline_id=published_pipeline.id,
                                        experiment_name='Batch_Prediction',
                                        recurrence=weekly)

# %% [markdown]
# ## Disable pipeline with active schedule

# %%
ss = Schedule.list(ws)
for s in ss:
    print(s)
# Out:
# Pipeline(Name: Weekly Predictions,
# Id: cda9ba75-7630-44e5-aae0-d20f6eb423e3,
# Status: Active,
# Pipeline Id: bb3d5fd1-92f0-4141-a6c7-e64ad9cb4547,
# Pipeline Endpoint Id: None,
# Recurrence Details: Runs at 2:00 on Monday every Week)

# %%
def stop_by_schedule_id(ws, schedule_id):
    s = next(s for s in Schedule.list(ws) if s.id == schedule_id)
    s.disable()
    return s

stop_by_schedule_id(ws, s.id)
# Out:
# Pipeline(Name: Weekly Predictions,
# Id: cda9ba75-7630-44e5-aae0-d20f6eb423e3,
# Status: Disabled,
# Pipeline Id: bb3d5fd1-92f0-4141-a6c7-e64ad9cb4547,
# Pipeline Endpoint Id: None,
# Recurrence Details: Runs at 2:00 on Monday every Week)
